# %%
# %load_ext autoreload
# %autoreload 2

# %%
from matplotlib.pyplot import imshow, figure
from bpoptimizer import Floor

# %%
floor = Floor("../tests/floors/valid_floor.png", interval=0.5)
floor.count
# Out:
# 100%|██████████| 16/16 [00:01<00:00, 15.83it/s]
# 16

# %%
imshow(floor.display())

# %%
floor.shuffle()
imshow(floor.display())

# %%
spots = floor.get_spots(10)
spots
# Out:
# 100%|██████████| 9216/9216 [00:00<00:00, 11763.87it/s]
# [(18.0, 29.5), (29.5, 17.5)]

# %%
figure(figsize=(floor.CANVAS_SCALE, floor.CANVAS_SCALE))
imshow(floor.display(spots[0], scale=50, path="result.png"))
