# %%
# %load_ext autoreload
# %autoreload 2

# %%
from matplotlib.pyplot import imshow, figure
from bpoptimizer import Floor

# %%
floor = Floor("../tests/floors/valid_floor.png")
floor.count
# Out:
# 16

# %%
imshow(floor.display())

# %%
floor.shuffle()
imshow(floor.display())

# %%
spots = floor.get_spots()
spots
# Out:
# 100%|██████████| 2304/2304 [00:04<00:00, 518.21it/s]
# [(23, 23), (23, 24), (24, 23), (24, 24)]

# %%
figure(figsize=(floor.CANVAS_SCALE, floor.CANVAS_SCALE))
imshow(floor.display(spots[0]))
