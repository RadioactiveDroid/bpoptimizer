# %%
from matplotlib.pyplot import imshow, figure
from bpoptimizer import Floor

# %%
floor = Floor("../floors/Fireworks.png", interval=0.1)
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 15.17it/s]

# %%
floor.shuffle()
imshow(floor.display())

# %%
distance = 4
spots = floor.get_spots(distance)
spots
# Out:
# array([[20.5, 31.5]])

# %%
scale = 50
figure(figsize=(scale, scale))
imshow(floor.display(spots[0], reachable_distance=distance, scale=scale, path="result.png"))
